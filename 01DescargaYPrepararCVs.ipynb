# %%
# Programa para descargar CVs de candidatos y organizarlos por Poder de la Unión
# Para usar en Google Colab

import pandas as pd
import requests
import os
import io
from google.colab import drive
import re
from urllib.parse import urlparse
from tqdm.notebook import tqdm
import mimetypes

# Montar Google Drive
drive.mount('/content/drive')

# Definir la ruta base donde se guardarán los CVs
BASE_PATH = '/content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs'

# Crear la carpeta base si no existe
os.makedirs(BASE_PATH, exist_ok=True)

# Leer el archivo Excel
def leer_excel(ruta_archivo):
    try:
        return pd.read_excel(ruta_archivo)
    except Exception as e:
        print(f"Error al leer el archivo Excel: {e}")
        return None

# Determinar el tipo de archivo basado en la URL o encabezados de respuesta
def obtener_extension_archivo(url, response=None):
    # Primero intentar obtener la extensión desde la URL
    parsed_url = urlparse(url)
    path = parsed_url.path
    extension = os.path.splitext(path)[1].lower()

    if extension and extension != '.':
        return extension

    # Si no hay extensión en la URL o es inválida, intentar con el Content-Type
    if response and 'Content-Type' in response.headers:
        content_type = response.headers['Content-Type'].split(';')[0].strip()
        ext = mimetypes.guess_extension(content_type)
        if ext:
            return ext

    # Si todo falla, asumimos que es un PDF (formato común para CVs)
    return '.pdf'

# Función para limpiar nombres de archivo
def limpiar_nombre_archivo(nombre):
    # Eliminar caracteres no permitidos en nombres de archivo
    nombre_limpio = re.sub(r'[\\/*?:"<>|]', "", nombre)
    # Reemplazar espacios por guiones bajos
    nombre_limpio = nombre_limpio.replace(' ', '_')
    # Limitar longitud del nombre
    if len(nombre_limpio) > 120:
        nombre_limpio = nombre_limpio[:120]
    return nombre_limpio

# Descargar y guardar CV
def descargar_cv(url, candidato, poder, edo, cargo):
    try:
        if not url or pd.isna(url):
            print(f"URL no válida para el candidato {candidato}")
            return False

        print(f"Descargando CV de: {candidato} - {url}")

        # Hacer la solicitud HTTP
        response = requests.get(url, stream=True, timeout=30)

        # Verificar si la solicitud fue exitosa
        if response.status_code == 200:
            # Obtener la extensión del archivo
            extension = obtener_extension_archivo(url, response)

            # Crear el nombre del archivo
            nombre_archivo = f"{limpiar_nombre_archivo(candidato)}{extension}"

            # Crear la carpeta para este poder si no existe
            poder_directorio = os.path.join(BASE_PATH, limpiar_nombre_archivo(poder))
            os.makedirs(poder_directorio, exist_ok=True)

            # Ruta completa donde se guardará el archivo
            ruta_completa = os.path.join(poder_directorio, nombre_archivo)

            # Guardar el archivo
            with open(ruta_completa, 'wb') as f:
                for chunk in response.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)

            print(f"CV guardado en: {ruta_completa}")

            # Crear archivo de metadatos (información adicional sobre el candidato)
            ruta_metadata = os.path.join(poder_directorio, f"{limpiar_nombre_archivo(candidato)}_metadata.txt")
            with open(ruta_metadata, 'w', encoding='utf-8') as f:
                f.write(f"Candidato: {candidato}\n")
                f.write(f"Poder de la Unión: {poder}\n")
                f.write(f"Estado: {edo}\n")
                f.write(f"Cargo: {cargo}\n")
                f.write(f"URL original: {url}\n")

            return True
        else:
            print(f"Error al descargar CV de {candidato}. Código de estado: {response.status_code}")
            return False

    except Exception as e:
        print(f"Error al procesar CV de {candidato}: {e}")
        return False

# Función principal
def main():
    # Definir la ruta del archivo Excel (ajustar según sea necesario)
    ruta_excel = '/content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/Candidatos_18-05-2025.xlsx'

    # Preguntar al usuario si desea usar otra ruta
    otra_ruta = input(f"El archivo Excel se buscará en: {ruta_excel}\n¿Desea especificar otra ubicación? (s/n): ")

    if otra_ruta.lower() == 's':
        ruta_excel = input("Ingrese la ruta completa del archivo Excel: ")

    # Leer el archivo Excel
    df = leer_excel(ruta_excel)

    if df is None:
        print("No se pudo leer el archivo Excel. El programa terminará.")
        return

    # Verificar que el DataFrame tenga las columnas necesarias
    columnas_requeridas = ['Edo', 'Cargo', 'Poder_de_la_Unión', 'Candidato', 'Url_del_Curriculum_Candidato']
    columnas_faltantes = [col for col in columnas_requeridas if col not in df.columns]

    if columnas_faltantes:
        print(f"El archivo Excel no contiene las siguientes columnas requeridas: {columnas_faltantes}")
        print("Las columnas disponibles son:", df.columns.tolist())
        return

    # Contar cuántos CVs hay por cada Poder de la Unión
    conteo_por_poder = df['Poder_de_la_Unión'].value_counts()
    print("\nDistribución de candidatos por Poder de la Unión:")
    for poder, conteo in conteo_por_poder.items():
        print(f"- {poder}: {conteo} candidatos")

    # Preguntar si desea continuar
    confirmar = input("\n¿Desea continuar con la descarga de los CVs? (s/n): ")
    if confirmar.lower() != 's':
        print("Operación cancelada por el usuario.")
        return

    # Contador de CVs descargados
    cvs_descargados = 0
    total_cvs = len(df)

    # Descargar los CVs con barra de progreso
    print(f"\nIniciando descarga de {total_cvs} CVs...")

    for _, fila in tqdm(df.iterrows(), total=total_cvs, desc="Descargando CVs"):
        resultado = descargar_cv(
            url=fila['Url_del_Curriculum_Candidato'],
            candidato=fila['Candidato'],
            poder=fila['Poder_de_la_Unión'],
            edo=fila['Edo'],
            cargo=fila['Cargo']
        )

        if resultado:
            cvs_descargados += 1

    # Mostrar resumen final
    print(f"\nResumen de la operación:")
    print(f"- Total de candidatos procesados: {total_cvs}")
    print(f"- CVs descargados exitosamente: {cvs_descargados}")
    print(f"- CVs no descargados: {total_cvs - cvs_descargados}")

    if cvs_descargados > 0:
        print(f"\nLos CVs se han guardado en: {BASE_PATH}")
        print("Organizados en carpetas según el Poder de la Unión.")

# Ejecutar el programa
if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# El archivo Excel se buscará en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/Candidatos_18-05-2025.xlsx
# ¿Desea especificar otra ubicación? (s/n): n
#
# Distribución de candidatos por Poder de la Unión:
# - Poder Legislativo: 47 candidatos
# - Poder Ejecutivo: 45 candidatos
# - Poder Judicial: 29 candidatos
# - En Funciones: 10 candidatos
# - Poder Ejecutivo, Poder Legislativo: 7 candidatos
# - Poder Ejecutivo, Poder Judicial: 5 candidatos
# - Poder Judicial, Poder Legislativo: 5 candidatos
# - Poder Ejecutivo, Poder Judicial, Poder Legislativo: 4 candidatos
# - En Funciones, Poder Ejecutivo: 1 candidatos
#
# ¿Desea continuar con la descarga de los CVs? (s/n): s
#
# Iniciando descarga de 153 CVs...
# Descargando CVs:   0%|          | 0/153 [00:00<?, ?it/s]
# Descargando CV de: CARRANZA BUENRROSTRO DIANA LAURA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/
pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/SANCHEZ_CASTILLO_MONICA.pdf
# Descargando CV de: URIBE OBREGON DENISSE DE LOS ANGELES - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/URIBE_OBREGON_DENISSE_DE_LOS_ANGELES_18485.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/URIBE_OBREGON_DENISSE_DE_LOS_ANGELES.pdf
# Descargando CV de: VERA MADRIGAL MARIA ELISA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/VERA_MADRIGAL_MARIA_ELISA_18545.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/VERA_MADRIGAL_MARIA_ELISA.pdf
# Descargando CV de: VILLA BEDOLLA HASUBA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/VILLA_BEDOLLA_HASUBA_18572.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/VILLA_BEDOLLA_HASUBA.pdf
# Descargando CV de: ALCUDIA VAZQUEZ JUAN PEDRO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ALCUDIA_VAZQUEZ_JUAN_PEDRO_14596.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ALCUDIA_VAZQUEZ_JUAN_PEDRO.pdf
# Descargando CV de: AVILA MARTINEZ OCTAVIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/AVILA_MARTINEZ_OCTAVIO_15082.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/AVILA_MARTINEZ_OCTAVIO.pdf
# Descargando CV de: BATIZ VAZQUEZ BERNARDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/BATIZ_VAZQUEZ_BERNARDO_14818.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/En_Funciones/BATIZ_VAZQUEZ_BERNARDO.pdf
# Descargando CV de: CARBAJAL DIAZ JUVENAL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CARBAJAL_DIAZ_JUVENAL_15115.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/CARBAJAL_DIAZ_JUVENAL.pdf
# Descargando CV de: CEJA GONZALEZ LUIS MIGUEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CEJA_GONZALEZ_LUIS_MIGUEL_15414.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/CEJA_GONZALEZ_LUIS_MIGUEL.pdf
# Descargando CV de: CLEMENTE PEREZ JORGE ALFREDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CLEMENTE_PEREZ_JORGE_ALFREDO_15549.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/CLEMENTE_PEREZ_JORGE_ALFREDO.pdf
# Descargando CV de: CRUZ RAMOS JORGE ANTONIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CRUZ_RAMOS_JORGE_ANTONIO_15322.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/CRUZ_RAMOS_JORGE_ANTONIO.pdf
# Descargando CV de: DE LOS SANTOS CRUZ MIGUEL ANGEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/DE_LOS_SANTOS_CRUZ_MIGUEL_ANGEL_15375.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/DE_LOS_SANTOS_CRUZ_MIGUEL_ANGEL.pdf
# Descargando CV de: FRANCO GUEVARA ADOLFO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/FRANCO_GUEVARA_ADOLFO_15686.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/FRANCO_GUEVARA_ADOLFO.pdf
# Descargando CV de: GALINZOGA ESPARZA GILDARDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GALINZOGA_ESPARZA_GILDARDO_16036.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/GALINZOGA_ESPARZA_GILDARDO.pdf
# Descargando CV de: H LEON TOVAR RUFINO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/H_LEON_TOVAR_RUFINO_16160.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/H_LEON_TOVAR_RUFINO.pdf
# Descargando CV de: JIMENEZ LOPEZ J. GUADALUPE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/JIMENEZ_LOPEZ_J._GUADALUPE_16480.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/JIMENEZ_LOPEZ_J._GUADALUPE.pdf
# Descargando CV de: LAGUNES LEANO JORGE ISAAC - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/LAGUNES_LEANO_JORGE_ISAAC_16369.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/LAGUNES_LEANO_JORGE_ISAAC.pdf
# Descargando CV de: MONTIEL FLORES EMANUEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MONTIEL_FLORES_EMANUEL_17170.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/MONTIEL_FLORES_EMANUEL.pdf
# Descargando CV de: RODRIGUEZ GARDUÑO ROGELIO ZACARIAS - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/
A - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GÜICHO_GONZALEZ_MONICA_ARCELIA_17.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/GÜICHO_GONZALEZ_MONICA_ARCELIA.pdf
# Descargando CV de: HERRERIAS GUERRA SARA IRENE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/HERRERIAS_GUERRA_SARA_IRENE_26.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/HERRERIAS_GUERRA_SARA_IRENE.pdf
# Descargando CV de: IBARRA OLGUIN ANA MARIA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/IBARRA_OLGUIN_ANA_MARIA_18.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Judicial/IBARRA_OLGUIN_ANA_MARIA.pdf
# Descargando CV de: MADRIGAL VALDEZ LUTGARDA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MADRIGAL_VALDEZ_LUTGARDA_29.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/MADRIGAL_VALDEZ_LUTGARDA.pdf
# Descargando CV de: MARTINEZ VALERO DORA ALICIA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MARTINEZ_VALERO_DORA_ALICIA_30.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial,_Poder_Legislativo/MARTINEZ_VALERO_DORA_ALICIA.pdf
# Descargando CV de: MORALES IBAÑEZ MARISELA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MORALES_IBAÑEZ_MARISELA_4102.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/MORALES_IBAÑEZ_MARISELA.pdf
# Descargando CV de: MOSRI GUTIERREZ MAGDA ZULEMA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MOSRI_GUTIERREZ_MAGDA_ZULEMA_31.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/MOSRI_GUTIERREZ_MAGDA_ZULEMA.pdf
# Descargando CV de: ORTIZ AHLF LORETTA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ORTIZ_AHLF_LORETTA_4105.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/En_Funciones/ORTIZ_AHLF_LORETTA.pdf
# Descargando CV de: ORTIZ MONROY CYNTHIA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ORTIZ_MONROY_CYNTHIA_32.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ORTIZ_MONROY_CYNTHIA.pdf
# Descargando CV de: PEREZ ROMO LORENA JOSEFINA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/PEREZ_ROMO_LORENA_JOSEFINA_19.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/PEREZ_ROMO_LORENA_JOSEFINA.pdf
# Descargando CV de: REYES TERAN ARELY - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/REYES_TERAN_ARELY_25.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/REYES_TERAN_ARELY.pdf
# Descargando CV de: RIOS GONZALEZ MARIA ESTELA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/RIOS_GONZALEZ_MARIA_ESTELA_27.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/RIOS_GONZALEZ_MARIA_ESTELA.pdf
# Descargando CV de: ROJAS OLVERA MARGARITA DARLENE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ROJAS_OLVERA_MARGARITA_DARLENE_28.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/ROJAS_OLVERA_MARGARITA_DARLENE.pdf
# Descargando CV de: ROSILLO GARFIAS MA. CONSUELO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ROSILLO_GARFIAS_MA._CONSUELO_37.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ROSILLO_GARFIAS_MA._CONSUELO.pdf
# URL no válida para el candidato SANTOS MENDOZA GLORIA ROSA
# Descargando CV de: TAPIA GUTIERREZ INGRID DE LOS ANGELES - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/TAPIA_GUTIERREZ_INGRID_DE_LOS_ANGELES_38.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/TAPIA_GUTIERREZ_INGRID_DE_LOS_ANGELES.pdf
# Descargando CV de: TELLEZ TORRES OROZCO NATALIA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/TELLEZ_TORRES_OROZCO_NATALIA_34.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/TELLEZ_TORRES_OROZCO_NATALIA.pdf
# Descargando CV de: UCARANZA SANCHEZ VERONICA ELIZABETH - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/UCARANZA_SANCHEZ_VERONICA_ELIZABETH_40.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/UCARANZA_SANCHEZ_VERONICA_ELIZABETH.pdf
# Descargando CV de: ZARZA DELGADO LUZ MARIA - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ZARZA_DELGADO_LUZ_MARIA_41.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ZARZA_DELGADO_LUZ_MARIA.pdf
# Descargando CV de: AGUILAR ORTIZ HUGO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/AGUILAR_ORTIZ_HUGO_35.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/AGUILAR_ORTIZ_HUGO.pdf
# Descargando CV de: ALLIER CAMPUZANO JAIME - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ALLIER_CAMPUZANO_JAIME_43.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/ALLIER_CAMPUZANO_JAIME.pdf
# Descargando CV de: ANAYA GALLARDO FEDERICO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ANAYA_GALLARDO_FEDERICO_36.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo,_Poder_Legislativo/ANAYA_GALLARDO_FEDERICO.pdf
# Descargando CV de: CARLIN DE LA FUENTE ULISES - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CARLIN_DE_LA_FUENTE_ULISES_45.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial,_Poder_Legislativo/CARLIN_DE_LA_FUENTE_ULISES.pdf
# Descargando CV de: CORZO SOSA EDGAR - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/CORZO_SOSA_EDGAR_46.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/CORZO_SOSA_EDGAR.pdf
# Descargando CV de: DAVILA RODRIGUEZ ABRAHAM AMIUD - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/DAVILA_RODRIGUEZ_ABRAHAM_AMIUD_47.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/DAVILA_RODRIGUEZ_ABRAHAM_AMIUD.pdf
# Descargando CV de: DE PAZ GONZALEZ ISAAC - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/DE_PAZ_GONZALEZ_ISAAC_231.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/DE_PAZ_GONZALEZ_ISAAC.pdf
# Descargando CV de: ESPINOSA BETANZO IRVING - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ESPINOSA_BETANZO_IRVING_236.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/ESPINOSA_BETANZO_IRVING.pdf
# Descargando CV de: ESPINOZA HERNANDEZ RAYMUNDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ESPINOZA_HERNANDEZ_RAYMUNDO_50.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ESPINOZA_HERNANDEZ_RAYMUNDO.pdf
# Descargando CV de: FIGUEROA MEJIA GIOVANNI AZAEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/FIGUEROA_MEJIA_GIOVANNI_AZAEL_240.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/FIGUEROA_MEJIA_GIOVANNI_AZAEL.pdf
# Descargando CV de: FLORES CASTRO MAURICIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/FLORES_CASTRO_MAURICIO_52.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/FLORES_CASTRO_MAURICIO.pdf
# Descargando CV de: GARCIA GONZALEZ JAIME SALVADOR - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GARCIA_GONZALEZ_JAIME_SALVADOR_53.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial,_Poder_Legislativo/GARCIA_GONZALEZ_JAIME_SALVADOR.pdf
# Descargando CV de: GARCIA GUERRA ANGEL MARIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GARCIA_GUERRA_ANGEL_MARIO_54.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial,_Poder_Legislativo/GARCIA_GUERRA_ANGEL_MARIO.pdf
# Descargando CV de: GARDUÑO PASTEN RICARDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GARDUÑO_PASTEN_RICARDO_4106.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/GARDUÑO_PASTEN_RICARDO.pdf
# Descargando CV de: GUERRERO GARCIA ARISTIDES RODRIGO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GUERRERO_GARCIA_ARISTIDES_RODRIGO_243.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/GUERRERO_GARCIA_ARISTIDES_RODRIGO.pdf
# Descargando CV de: GUTIERREZ PRIEGO CESAR MARIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/GUTIERREZ_PRIEGO_CESAR_MARIO_56.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/GUTIERREZ_PRIEGO_CESAR_MARIO.pdf
# Descargando CV de: HERNANDEZ PALACIOS MIRON LUIS RAFAEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/HERNANDEZ_PALACIOS_MIRON_LUIS_RAFAEL_244.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/HERNANDEZ_PALACIOS_MIRON_LUIS_RAFAEL.pdf
# Descargando CV de: ILLANES OLIVARES ROBERTO SALVADOR - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ILLANES_OLIVARES_ROBERTO_SALVADOR_58.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/ILLANES_OLIVARES_ROBERTO_SALVADOR.pdf
# Descargando CV de: JIMENEZ GUTIERREZ JAVIER - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/JIMENEZ_GUTIERREZ_JAVIER_246.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/JIMENEZ_GUTIERREZ_JAVIER.pdf
# Descargando CV de: LOPEZ ANDRADE GUILLERMO PABLO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/LOPEZ_ANDRADE_GUILLERMO_PABLO_4049.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/LOPEZ_ANDRADE_GUILLERMO_PABLO.pdf
# Descargando CV de: LUNA JAIME FRANCISCO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/LUNA_JAIME_FRANCISCO_60.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/LUNA_JAIME_FRANCISCO.pdf
# Descargando CV de: MOLINA MARTINEZ SERGIO JAVIER - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MOLINA_MARTINEZ_SERGIO_JAVIER_61.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/MOLINA_MARTINEZ_SERGIO_JAVIER.pdf
# Descargando CV de: MOLINAR ROHANA LUIS EDWIN - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/MOLINAR_ROHANA_LUIS_EDWIN_250.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/MOLINAR_ROHANA_LUIS_EDWIN.pdf
# Descargando CV de: ODRIOZOLA MARISCAL CARLOS ENRIQUE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/ODRIOZOLA_MARISCAL_CARLOS_ENRIQUE_63.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/ODRIOZOLA_MARISCAL_CARLOS_ENRIQUE.pdf
# Descargando CV de: OLMEDO PIÑA CESAR ENRIQUE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/OLMEDO_PIÑA_CESAR_ENRIQUE_64.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial,_Poder_Legislativo/OLMEDO_PIÑA_CESAR_ENRIQUE.pdf
# Descargando CV de: REGIS LOPEZ GABRIEL - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/REGIS_LOPEZ_GABRIEL_254.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/REGIS_LOPEZ_GABRIEL.pdf
# Descargando CV de: SANTILLAN PEREZ EDUARDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/SANTILLAN_PEREZ_EDUARDO_256.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/SANTILLAN_PEREZ_EDUARDO.pdf
# Descargando CV de: SODI CUELLAR RICARDO ALFREDO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/SODI_CUELLAR_RICARDO_ALFREDO_66.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/SODI_CUELLAR_RICARDO_ALFREDO.pdf
# Descargando CV de: SORELA CASTILLO ANTONIO - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/SORELA_CASTILLO_ANTONIO_259.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Ejecutivo/SORELA_CASTILLO_ANTONIO.pdf
# Descargando CV de: TORRES MALDONADO EDUARDO JOSE - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/TORRES_MALDONADO_EDUARDO_JOSE_67.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Legislativo/TORRES_MALDONADO_EDUARDO_JOSE.pdf
# Descargando CV de: TORTOLERO SERRANO MAURICIO RICARDO III - https://candidaturaspoderjudicial.ine.mx/cycc/documentos/ficha/TORTOLERO_SERRANO_MAURICIO_RICARDO_III_4107.pdf
# CV guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs/Poder_Judicial/TORTOLERO_SERRANO_MAURICIO_RICARDO_III.pdf
#
# Resumen de la operación:
# - Total de candidatos procesados: 153
# - CVs descargados exitosamente: 152
# - CVs no descargados: 1
#
# Los CVs se han guardado en: /content/drive/My Drive/Colab Notebooks/AnalisisCandidatosPoderJudicialdelaFederación/CVs
# Organizados en carpetas según el Poder de la Unión.
